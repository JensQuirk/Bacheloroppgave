# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('SimResults/DACAPSimulations/dacapTestSimData.csv')
df.plot(x='Poisson Period', kind='line', stacked=False)
plt.show()

# %%
fig=plt.figure()
plt.plot()
# Out:
# []
